# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Using helper functions in src/data/load/data_loader

# %%
import random
from data.load.data_loader import get_codecfake_audio_id_list, load_audio_data

# %%
audio_ids = get_codecfake_audio_id_list()
len(audio_ids)
# Out:
# 35373

# %%
# It won't download the data to local disk. Instead, it streams the data directly from HuggingFace,
# holding only one sample in memory at each iteration.

random_audio_ids = random.sample(audio_ids, 5)
iterable_dataset = load_audio_data(
    audio_ids=random_audio_ids,
    dataset='codecfake'
)

for sample in iterable_dataset:
    print(sample)
# Out:
# {'audio': {'path': 'F01_p310_044.flac', 'array': array([-0.00521851, -0.00527954, -0.00531006, ..., -0.00335693,
#        -0.00335693, -0.00332642]), 'sampling_rate': 16000}, 'audio_id': 'p310_044', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p310_044.flac', 'array': array([ 0.00112915,  0.00125122,  0.00125122, ..., -0.00280762,
#        -0.00265503, -0.00286865]), 'sampling_rate': 48000}, 'audio_id': 'p310_044', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F02_p310_044.flac', 'array': array([ 1.06811523e-03,  1.70898438e-03,  1.28173828e-03, ...,
#         5.49316406e-04,  6.10351562e-05, -1.22070312e-04]), 'sampling_rate': 16000}, 'audio_id': 'p310_044', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p310_044.flac', 'array': array([0.00421143, 0.00418091, 0.00424194, ..., 0.00863647, 0.00878906,
#        0.00888062]), 'sampling_rate': 16000}, 'audio_id': 'p310_044', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F03_p310_044.flac', 'array': array([0.00421143, 0.00418091, 0.00424194, ..., 0.00863647, 0.00878906,
#        0.00888062]), 'sampling_rate': 16000}, 'audio_id': 'p310_044', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p310_044.flac', 'array': array([ 0.00262451,  0.00149536,  0.00161743, ..., -0.00537109,
#        -0.00531006, -0.00531006]), 'sampling_rate': 24000}, 'audio_id': 'p310_044', 'real_or_fake': 'F04'}
# {'audio': {'path': 'R_p310_044.flac', 'array': array([ 0.00112915,  0.0012207 ,  0.00106812, ..., -0.00747681,
#        -0.00692749, -0.00830078]), 'sampling_rate': 48000}, 'audio_id': 'p310_044', 'real_or_fake': 'R'}
# {'audio': {'path': 'F01_p260_007.flac', 'array': array([0.00421143, 0.00405884, 0.0039978 , ..., 0.00628662, 0.00576782,
#        0.00643921]), 'sampling_rate': 16000}, 'audio_id': 'p260_007', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p260_007.flac', 'array': array([-0.00708008, -0.00720215, -0.00750732, ...,  0.00021362,
#         0.00012207,  0.00036621]), 'sampling_rate': 48000}, 'audio_id': 'p260_007', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F02_p260_007.flac', 'array': array([-0.00268555, -0.0027771 , -0.00317383, ..., -0.00311279,
#        -0.00292969, -0.00280762]), 'sampling_rate': 16000}, 'audio_id': 'p260_007', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p260_007.flac', 'array': array([0.0012207 , 0.00119019, 0.00109863, ..., 0.00390625, 0.00442505,
#        0.00500488]), 'sampling_rate': 16000}, 'audio_id': 'p260_007', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F03_p260_007.flac', 'array': array([0.0012207 , 0.00119019, 0.00109863, ..., 0.00390625, 0.00442505,
#        0.00500488]), 'sampling_rate': 16000}, 'audio_id': 'p260_007', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p260_007.flac', 'array': array([-0.00238037, -0.00195312, -0.00189209, ..., -0.00021362,
#        -0.00021362, -0.00018311]), 'sampling_rate': 24000}, 'audio_id': 'p260_007', 'real_or_fake': 'F04'}
# {'audio': {'path': 'R_p260_007.flac', 'array': array([-0.00598145, -0.00793457, -0.00723267, ..., -0.00534058,
#        -0.00506592, -0.00561523]), 'sampling_rate': 48000}, 'audio_id': 'p260_007', 'real_or_fake': 'R'}
# {'audio': {'path': 'R_p241_016.flac', 'array': array([ 0.        , -0.00039673, -0.00039673, ..., -0.00204468,
#        -0.00241089, -0.00180054]), 'sampling_rate': 48000}, 'audio_id': 'p241_016', 'real_or_fake': 'R'}
# {'audio': {'path': 'F04_p241_016.flac', 'array': array([0.0010376 , 0.00033569, 0.00039673, ..., 0.00360107, 0.00363159,
#        0.00357056]), 'sampling_rate': 24000}, 'audio_id': 'p241_016', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p241_016.flac', 'array': array([0.00167847, 0.0027771 , 0.00222778, ..., 0.00317383, 0.00201416,
#        0.00265503]), 'sampling_rate': 16000}, 'audio_id': 'p241_016', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F02_p241_016.flac', 'array': array([2.74658203e-04, 2.44140625e-04, 3.05175781e-05, ...,
#        1.95312500e-03, 1.61743164e-03, 1.37329102e-03]), 'sampling_rate': 16000}, 'audio_id': 'p241_016', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p241_016.flac', 'array': array([0.00167847, 0.0027771 , 0.00222778, ..., 0.00317383, 0.00201416,
#        0.00265503]), 'sampling_rate': 16000}, 'audio_id': 'p241_016', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F01_p241_016.flac', 'array': array([ 0.00698853,  0.00701904,  0.00698853, ..., -0.00094604,
#        -0.00021362,  0.00131226]), 'sampling_rate': 16000}, 'audio_id': 'p241_016', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p241_016.flac', 'array': array([-6.10351562e-05, -1.22070312e-04,  0.00000000e+00, ...,
#        -4.88281250e-03, -5.15747070e-03, -5.09643555e-03]), 'sampling_rate': 48000}, 'audio_id': 'p241_016', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F05_p255_373.flac', 'array': array([-0.0015564 , -0.0017395 , -0.00143433, ..., -0.00061035,
#        -0.00131226, -0.00085449]), 'sampling_rate': 48000}, 'audio_id': 'p255_373', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p255_373.flac', 'array': array([-0.01571655, -0.01571655, -0.015625  , ..., -0.01422119,
#        -0.01425171, -0.01425171]), 'sampling_rate': 16000}, 'audio_id': 'p255_373', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F06_p255_373.flac', 'array': array([ 0.00222778,  0.00231934,  0.00204468, ..., -0.0043335 ,
#        -0.00421143, -0.00424194]), 'sampling_rate': 16000}, 'audio_id': 'p255_373', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F02_p255_373.flac', 'array': array([-0.00286865, -0.00250244, -0.00262451, ..., -0.00152588,
#        -0.00131226, -0.00164795]), 'sampling_rate': 16000}, 'audio_id': 'p255_373', 'real_or_fake': 'F02'}
# {'audio': {'path': 'R_p255_373.flac', 'array': array([-0.00271606, -0.00415039, -0.00335693, ..., -0.00054932,
#        -0.00088501, -0.00048828]), 'sampling_rate': 48000}, 'audio_id': 'p255_373', 'real_or_fake': 'R'}
# {'audio': {'path': 'F03_p255_373.flac', 'array': array([ 0.00222778,  0.00231934,  0.00204468, ..., -0.0043335 ,
#        -0.00421143, -0.00424194]), 'sampling_rate': 16000}, 'audio_id': 'p255_373', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p255_373.flac', 'array': array([-0.00064087, -0.00073242, -0.00079346, ...,  0.00079346,
#         0.00082397,  0.00076294]), 'sampling_rate': 24000}, 'audio_id': 'p255_373', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F06_p329_228.flac', 'array': array([0.01116943, 0.01119995, 0.01055908, ..., 0.01467896, 0.01467896,
#        0.0145874 ]), 'sampling_rate': 16000}, 'audio_id': 'p329_228', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F02_p329_228.flac', 'array': array([0.00167847, 0.00164795, 0.00177002, ..., 0.00057983, 0.00039673,
#        0.00027466]), 'sampling_rate': 16000}, 'audio_id': 'p329_228', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F05_p329_228.flac', 'array': array([0.00112915, 0.00125122, 0.00125122, ..., 0.00640869, 0.0062561 ,
#        0.00640869]), 'sampling_rate': 48000}, 'audio_id': 'p329_228', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p329_228.flac', 'array': array([0.00622559, 0.00631714, 0.00637817, ..., 0.02124023, 0.02105713,
#        0.02133179]), 'sampling_rate': 16000}, 'audio_id': 'p329_228', 'real_or_fake': 'F01'}
# {'audio': {'path': 'R_p329_228.flac', 'array': array([0.00192261, 0.00238037, 0.00231934, ..., 0.00842285, 0.0083313 ,
#        0.00875854]), 'sampling_rate': 48000}, 'audio_id': 'p329_228', 'real_or_fake': 'R'}
# {'audio': {'path': 'F04_p329_228.flac', 'array': array([ 0.00219727,  0.00109863,  0.00128174, ..., -0.00845337,
#        -0.00842285, -0.00830078]), 'sampling_rate': 24000}, 'audio_id': 'p329_228', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p329_228.flac', 'array': array([0.01116943, 0.01119995, 0.01055908, ..., 0.01467896, 0.01467896,
#        0.0145874 ]), 'sampling_rate': 16000}, 'audio_id': 'p329_228', 'real_or_fake': 'F03'}

# %%
# It will download the data to the local disk and cache it in the specified cache directory.
# So, next time, if you try to access an audio ID from any of the cached parquet files, it will be retrieved from the local cache folder.
# Note: Total space consumed by all 381 parquet files is around 20GB.
# It still holds only one sample in memory at each iteration.

random.seed(5)
random_audio_ids = random.sample(audio_ids, 5)
iterable_dataset = load_audio_data(
    audio_ids=random_audio_ids,
    dataset='codecfake',
    cache_dir='./cache'
)

for sample in iterable_dataset:
    print(sample)
# Out:
# {'audio': {'path': 'R_p278_119.flac', 'array': array([-4.27246094e-04, -9.15527344e-05, -4.27246094e-04, ...,
#        -8.85009766e-04, -7.93457031e-04, -7.93457031e-04]), 'sampling_rate': 48000}, 'audio_id': 'p278_119', 'real_or_fake': 'R'}
# {'audio': {'path': 'F04_p278_119.flac', 'array': array([ 5.18798828e-04, -9.15527344e-05,  1.52587891e-04, ...,
#        -9.76562500e-04, -9.76562500e-04, -9.76562500e-04]), 'sampling_rate': 24000}, 'audio_id': 'p278_119', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p278_119.flac', 'array': array([0.00167847, 0.00219727, 0.00231934, ..., 0.00686646, 0.00668335,
#        0.0067749 ]), 'sampling_rate': 16000}, 'audio_id': 'p278_119', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F02_p278_119.flac', 'array': array([ 2.13623047e-04,  0.00000000e+00, -2.44140625e-04, ...,
#         3.35693359e-04,  9.15527344e-05, -1.83105469e-04]), 'sampling_rate': 16000}, 'audio_id': 'p278_119', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p278_119.flac', 'array': array([0.00167847, 0.00219727, 0.00231934, ..., 0.00686646, 0.00668335,
#        0.0067749 ]), 'sampling_rate': 16000}, 'audio_id': 'p278_119', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F01_p278_119.flac', 'array': array([0.00119019, 0.00119019, 0.00128174, ..., 0.00228882, 0.00213623,
#        0.00204468]), 'sampling_rate': 16000}, 'audio_id': 'p278_119', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p278_119.flac', 'array': array([-6.10351562e-05, -1.22070312e-04,  0.00000000e+00, ...,
#        -1.58691406e-03, -1.64794922e-03, -1.86157227e-03]), 'sampling_rate': 48000}, 'audio_id': 'p278_119', 'real_or_fake': 'F05'}
# {'audio': {'path': 'R_p302_232.flac', 'array': array([0.00045776, 0.00039673, 0.00027466, ..., 0.00314331, 0.00280762,
#        0.00302124]), 'sampling_rate': 48000}, 'audio_id': 'p302_232', 'real_or_fake': 'R'}
# {'audio': {'path': 'F04_p302_232.flac', 'array': array([ 4.27246094e-04, -6.10351562e-05,  1.22070312e-04, ...,
#         2.47192383e-03,  2.50244141e-03,  2.50244141e-03]), 'sampling_rate': 24000}, 'audio_id': 'p302_232', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p302_232.flac', 'array': array([ 0.00234985,  0.00271606,  0.00292969, ..., -0.02487183,
#        -0.0244751 , -0.0244751 ]), 'sampling_rate': 16000}, 'audio_id': 'p302_232', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F02_p302_232.flac', 'array': array([-0.00067139, -0.00042725, -0.00033569, ...,  0.0007019 ,
#         0.00033569,  0.00054932]), 'sampling_rate': 16000}, 'audio_id': 'p302_232', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p302_232.flac', 'array': array([ 0.00234985,  0.00271606,  0.00292969, ..., -0.02487183,
#        -0.0244751 , -0.0244751 ]), 'sampling_rate': 16000}, 'audio_id': 'p302_232', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F01_p302_232.flac', 'array': array([ 0.02529907,  0.02536011,  0.02554321, ..., -0.00506592,
#        -0.00506592, -0.00491333]), 'sampling_rate': 16000}, 'audio_id': 'p302_232', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p302_232.flac', 'array': array([0.00112915, 0.00125122, 0.00125122, ..., 0.00106812, 0.0012207 ,
#        0.00125122]), 'sampling_rate': 48000}, 'audio_id': 'p302_232', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F04_p364_208.flac', 'array': array([ 0.00012207, -0.00027466,  0.        , ...,  0.00250244,
#         0.00250244,  0.00250244]), 'sampling_rate': 24000}, 'audio_id': 'p364_208', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p364_208.flac', 'array': array([0.00521851, 0.00570679, 0.00524902, ..., 0.01049805, 0.01119995,
#        0.01190186]), 'sampling_rate': 16000}, 'audio_id': 'p364_208', 'real_or_fake': 'F03'}
# {'audio': {'path': 'R_p364_208.flac', 'array': array([ 9.15527344e-05, -5.18798828e-04, -3.35693359e-04, ...,
#        -1.43432617e-03, -1.15966797e-03, -1.19018555e-03]), 'sampling_rate': 48000}, 'audio_id': 'p364_208', 'real_or_fake': 'R'}
# {'audio': {'path': 'F02_p364_208.flac', 'array': array([-0.00238037, -0.00299072, -0.003479  , ...,  0.00143433,
#         0.00125122,  0.00100708]), 'sampling_rate': 16000}, 'audio_id': 'p364_208', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p364_208.flac', 'array': array([0.00521851, 0.00570679, 0.00524902, ..., 0.01049805, 0.01119995,
#        0.01190186]), 'sampling_rate': 16000}, 'audio_id': 'p364_208', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F01_p364_208.flac', 'array': array([-0.00213623, -0.00216675, -0.00210571, ...,  0.00650024,
#         0.00674438,  0.00759888]), 'sampling_rate': 16000}, 'audio_id': 'p364_208', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p364_208.flac', 'array': array([0.00112915, 0.00125122, 0.00125122, ..., 0.00143433, 0.00164795,
#        0.00152588]), 'sampling_rate': 48000}, 'audio_id': 'p364_208', 'real_or_fake': 'F05'}
# {'audio': {'path': 'R_p231_270.flac', 'array': array([ 0.00570679,  0.00772095,  0.00692749, ..., -0.00228882,
#        -0.00158691, -0.00201416]), 'sampling_rate': 48000}, 'audio_id': 'p231_270', 'real_or_fake': 'R'}
# {'audio': {'path': 'F03_p231_270.flac', 'array': array([0.00604248, 0.00595093, 0.00592041, ..., 0.01165771, 0.01174927,
#        0.01174927]), 'sampling_rate': 16000}, 'audio_id': 'p231_270', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p231_270.flac', 'array': array([ 0.00588989,  0.00411987,  0.0043335 , ..., -0.00518799,
#        -0.00515747, -0.00518799]), 'sampling_rate': 24000}, 'audio_id': 'p231_270', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F05_p231_270.flac', 'array': array([ 2.04467773e-03,  2.01416016e-03,  2.04467773e-03, ...,
#         1.22070312e-04,  1.52587891e-04, -9.15527344e-05]), 'sampling_rate': 48000}, 'audio_id': 'p231_270', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p231_270.flac', 'array': array([-0.00079346, -0.00061035, -0.00064087, ..., -0.00509644,
#        -0.00531006, -0.00521851]), 'sampling_rate': 16000}, 'audio_id': 'p231_270', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F06_p231_270.flac', 'array': array([0.00604248, 0.00595093, 0.00592041, ..., 0.01165771, 0.01174927,
#        0.01174927]), 'sampling_rate': 16000}, 'audio_id': 'p231_270', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F02_p231_270.flac', 'array': array([-0.0017395 , -0.00125122, -0.00152588, ..., -0.00411987,
#        -0.00415039, -0.00393677]), 'sampling_rate': 16000}, 'audio_id': 'p231_270', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F05_p335_263.flac', 'array': array([-0.0015564 , -0.0017395 , -0.00143433, ...,  0.00302124,
#         0.00308228,  0.00320435]), 'sampling_rate': 48000}, 'audio_id': 'p335_263', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p335_263.flac', 'array': array([ 0.00344849,  0.00344849,  0.00344849, ..., -0.00311279,
#        -0.00314331, -0.00317383]), 'sampling_rate': 16000}, 'audio_id': 'p335_263', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F06_p335_263.flac', 'array': array([0.00262451, 0.00247192, 0.00238037, ..., 0.0039978 , 0.00384521,
#        0.00405884]), 'sampling_rate': 16000}, 'audio_id': 'p335_263', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F02_p335_263.flac', 'array': array([-0.00036621, -0.00027466, -0.00045776, ..., -0.00042725,
#        -0.00036621, -0.00076294]), 'sampling_rate': 16000}, 'audio_id': 'p335_263', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F03_p335_263.flac', 'array': array([0.00262451, 0.00247192, 0.00238037, ..., 0.0039978 , 0.00384521,
#        0.00405884]), 'sampling_rate': 16000}, 'audio_id': 'p335_263', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p335_263.flac', 'array': array([-0.00073242, -0.00085449, -0.00067139, ...,  0.00549316,
#         0.00552368,  0.00549316]), 'sampling_rate': 24000}, 'audio_id': 'p335_263', 'real_or_fake': 'F04'}
# {'audio': {'path': 'R_p335_263.flac', 'array': array([-0.00308228, -0.00473022, -0.00448608, ...,  0.00283813,
#         0.00317383,  0.00219727]), 'sampling_rate': 48000}, 'audio_id': 'p335_263', 'real_or_fake': 'R'}

# %% [markdown]
# ### Code to load codecfake data from HuggingFace (without helper functions in src module)

# %%
import os
import time
import random

import json
import requests

import numpy as np
import matplotlib.pyplot as plt

import librosa

from datasets import load_dataset, Audio
from collections import defaultdict

# %%
from utils.config import load_config

config      = load_config()
cache_files = config['data_paths']['codecfake']['cache_files']

# %%
username      = "ajaykarthick"
dataset_name  = "codecfake-audio"
repo_id       = f"{username}/{dataset_name}"
json_file_url = f"https://huggingface.co/datasets/{repo_id}/resolve/main/audio_id_to_file_map.json"

# %%
# Get the Audio ID to Parquet File Map
response = requests.get(json_file_url)
response.raise_for_status()
audio_id_to_file_map = response.json()

# %% [markdown]
# ### Stream from HuggingFace Datasets (without Downloading datasets)

# %%
def get_dataset(audio_id):
    parquet_file = audio_id_to_file_map[audio_id]
    iterable_ds = load_dataset("parquet", data_files=parquet_file, split="train", streaming=True)
    dataset = iterable_ds.filter(lambda example: example['audio_id'] == audio_id)
    return dataset

audio_ids = list(audio_id_to_file_map.keys())
audio_id = audio_ids[-1]

start_time = time.time()

for example in get_dataset(audio_id):
    print(example)
    
current_time = time.time()
print(f"Time elapsed: {current_time - start_time} seconds")
# Out:
# {'audio': {'path': 'R_p376_295.flac', 'array': array([-0.00546265, -0.0085144 , -0.00708008, ..., -0.01385498,
#        -0.01327515, -0.01489258]), 'sampling_rate': 48000}, 'audio_id': 'p376_295', 'real_or_fake': 'R'}
# {'audio': {'path': 'F04_p376_295.flac', 'array': array([-0.00265503, -0.00244141, -0.0022583 , ..., -0.01498413,
#        -0.0149231 , -0.01489258]), 'sampling_rate': 24000}, 'audio_id': 'p376_295', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p376_295.flac', 'array': array([ 0.00158691,  0.00146484,  0.00158691, ..., -0.01025391,
#        -0.01049805, -0.01074219]), 'sampling_rate': 16000}, 'audio_id': 'p376_295', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F02_p376_295.flac', 'array': array([-0.00448608, -0.00445557, -0.00537109, ...,  0.00067139,
#         0.00033569,  0.00042725]), 'sampling_rate': 16000}, 'audio_id': 'p376_295', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F05_p376_295.flac', 'array': array([-0.00708008, -0.00720215, -0.00750732, ..., -0.0055542 ,
#        -0.00531006, -0.00570679]), 'sampling_rate': 48000}, 'audio_id': 'p376_295', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p376_295.flac', 'array': array([-0.00552368, -0.00543213, -0.00509644, ...,  0.00128174,
#         0.00106812,  0.00119019]), 'sampling_rate': 16000}, 'audio_id': 'p376_295', 'real_or_fake': 'F01'}
# Time elapsed: 6.201108455657959 seconds

# %% [markdown]
# ### Stream more than one audio ID from single parquet file

# %%
from datasets import load_dataset

def get_dataset(audio_ids):
    if isinstance(audio_ids, str):
        audio_ids = [audio_ids]

    # Check if all audio_ids belong to the same parquet file
    parquet_file = audio_id_to_file_map[audio_ids[0]]
    for audio_id in audio_ids:
        if audio_id_to_file_map[audio_id] != parquet_file:
            raise ValueError("Not all audio_ids belong to the same parquet file")

    iterable_ds = load_dataset("parquet", data_files=parquet_file, split="train", streaming=True)
    
    # Filter the dataset to include only the desired audio_ids
    dataset = iterable_ds.filter(lambda example: example['audio_id'] in audio_ids)
    return dataset


audio_ids = list(audio_id_to_file_map.keys())[:10] 

start_time = time.time()

dataset = get_dataset(audio_ids)
for example in dataset:
    print(example)

current_time = time.time()
print(f"Total time elapsed: {current_time - start_time} seconds")
# Out:
# {'audio': {'path': 'R_p225_002.flac', 'array': array([-0.0045166 , -0.00665283, -0.006073  , ...,  0.00723267,
#         0.00668335,  0.00775146]), 'sampling_rate': 48000}, 'audio_id': 'p225_002', 'real_or_fake': 'R'}
# {'audio': {'path': 'F03_p225_002.flac', 'array': array([0.00195312, 0.0015564 , 0.00164795, ..., 0.00265503, 0.00244141,
#        0.00262451]), 'sampling_rate': 16000}, 'audio_id': 'p225_002', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p225_002.flac', 'array': array([-0.0012207 , -0.00112915, -0.0010376 , ...,  0.00564575,
#         0.00564575,  0.00558472]), 'sampling_rate': 24000}, 'audio_id': 'p225_002', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F01_p225_002.flac', 'array': array([ 0.00186157,  0.00192261,  0.00195312, ..., -0.00888062,
#        -0.00888062, -0.00894165]), 'sampling_rate': 16000}, 'audio_id': 'p225_002', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p225_002.flac', 'array': array([-0.00335693, -0.0032959 , -0.00320435, ...,  0.00796509,
#         0.00772095,  0.00814819]), 'sampling_rate': 48000}, 'audio_id': 'p225_002', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F02_p225_002.flac', 'array': array([-0.00247192, -0.00231934, -0.00244141, ...,  0.00128174,
#         0.00128174,  0.00112915]), 'sampling_rate': 16000}, 'audio_id': 'p225_002', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p225_002.flac', 'array': array([0.00195312, 0.0015564 , 0.00164795, ..., 0.00265503, 0.00244141,
#        0.00262451]), 'sampling_rate': 16000}, 'audio_id': 'p225_002', 'real_or_fake': 'F06'}
# {'audio': {'path': 'R_p225_003.flac', 'array': array([-0.00369263, -0.00476074, -0.00457764, ...,  0.00134277,
#         0.00177002,  0.00177002]), 'sampling_rate': 48000}, 'audio_id': 'p225_003', 'real_or_fake': 'R'}
# {'audio': {'path': 'F04_p225_003.flac', 'array': array([-0.00027466, -0.00033569, -0.00021362, ..., -0.00405884,
#        -0.00402832, -0.0039978 ]), 'sampling_rate': 24000}, 'audio_id': 'p225_003', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p225_003.flac', 'array': array([0.00131226, 0.00149536, 0.00161743, ..., 0.00115967, 0.00067139,
#        0.0012207 ]), 'sampling_rate': 16000}, 'audio_id': 'p225_003', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F06_p225_003.flac', 'array': array([0.00131226, 0.00149536, 0.00161743, ..., 0.00115967, 0.00067139,
#        0.0012207 ]), 'sampling_rate': 16000}, 'audio_id': 'p225_003', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F02_p225_003.flac', 'array': array([-0.00549316, -0.00537109, -0.00537109, ..., -0.00061035,
#        -0.00073242, -0.00085449]), 'sampling_rate': 16000}, 'audio_id': 'p225_003', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F05_p225_003.flac', 'array': array([-0.00335693, -0.0032959 , -0.00320435, ..., -0.00033569,
#        -0.00039673, -0.00027466]), 'sampling_rate': 48000}, 'audio_id': 'p225_003', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p225_003.flac', 'array': array([0.00469971, 0.00473022, 0.00485229, ..., 0.00064087, 0.0005188 ,
#        0.00073242]), 'sampling_rate': 16000}, 'audio_id': 'p225_003', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F04_p225_005.flac', 'array': array([ 0.0007019 ,  0.00015259,  0.00039673, ..., -0.00100708,
#        -0.00097656, -0.00100708]), 'sampling_rate': 24000}, 'audio_id': 'p225_005', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p225_005.flac', 'array': array([0.00106812, 0.00152588, 0.0017395 , ..., 0.00073242, 0.00030518,
#        0.00137329]), 'sampling_rate': 16000}, 'audio_id': 'p225_005', 'real_or_fake': 'F03'}
# {'audio': {'path': 'R_p225_005.flac', 'array': array([ 0.00021362,  0.00012207,  0.00027466, ..., -0.00189209,
#        -0.00167847, -0.00216675]), 'sampling_rate': 48000}, 'audio_id': 'p225_005', 'real_or_fake': 'R'}
# {'audio': {'path': 'F06_p225_005.flac', 'array': array([0.00106812, 0.00152588, 0.0017395 , ..., 0.00073242, 0.00030518,
#        0.00137329]), 'sampling_rate': 16000}, 'audio_id': 'p225_005', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F02_p225_005.flac', 'array': array([-0.00244141, -0.00231934, -0.00262451, ..., -0.00039673,
#        -0.00048828, -0.00048828]), 'sampling_rate': 16000}, 'audio_id': 'p225_005', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F05_p225_005.flac', 'array': array([ 0.00112915,  0.00125122,  0.00125122, ..., -0.00186157,
#        -0.00189209, -0.00192261]), 'sampling_rate': 48000}, 'audio_id': 'p225_005', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p225_005.flac', 'array': array([ 3.32641602e-03,  3.32641602e-03,  3.23486328e-03, ...,
#        -9.15527344e-05, -1.83105469e-04, -2.13623047e-04]), 'sampling_rate': 16000}, 'audio_id': 'p225_005', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p225_006.flac', 'array': array([ 0.00112915,  0.00125122,  0.00125122, ..., -0.00588989,
#        -0.00592041, -0.00610352]), 'sampling_rate': 48000}, 'audio_id': 'p225_006', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p225_006.flac', 'array': array([0.00476074, 0.00476074, 0.00485229, ..., 0.00558472, 0.00549316,
#        0.00549316]), 'sampling_rate': 16000}, 'audio_id': 'p225_006', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F06_p225_006.flac', 'array': array([ 0.00131226,  0.00140381,  0.00140381, ..., -0.00372314,
#        -0.00390625, -0.00384521]), 'sampling_rate': 16000}, 'audio_id': 'p225_006', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F02_p225_006.flac', 'array': array([ 0.00085449,  0.00073242,  0.00039673, ..., -0.00213623,
#        -0.00216675, -0.00195312]), 'sampling_rate': 16000}, 'audio_id': 'p225_006', 'real_or_fake': 'F02'}
# {'audio': {'path': 'R_p225_006.flac', 'array': array([ 0.00015259,  0.00048828,  0.00042725, ..., -0.0071106 ,
#        -0.0078125 , -0.00524902]), 'sampling_rate': 48000}, 'audio_id': 'p225_006', 'real_or_fake': 'R'}
# {'audio': {'path': 'F03_p225_006.flac', 'array': array([ 0.00131226,  0.00140381,  0.00140381, ..., -0.00372314,
#        -0.00390625, -0.00384521]), 'sampling_rate': 16000}, 'audio_id': 'p225_006', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p225_006.flac', 'array': array([ 0.00018311, -0.00021362, -0.00021362, ..., -0.0050354 ,
#        -0.00500488, -0.0050354 ]), 'sampling_rate': 24000}, 'audio_id': 'p225_006', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F02_p225_007.flac', 'array': array([ 3.05175781e-05,  9.15527344e-05,  3.05175781e-05, ...,
#        -6.10351562e-04, -8.54492188e-04, -7.01904297e-04]), 'sampling_rate': 16000}, 'audio_id': 'p225_007', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p225_007.flac', 'array': array([ 0.0017395 ,  0.00164795,  0.00183105, ..., -0.00692749,
#        -0.00692749, -0.00674438]), 'sampling_rate': 16000}, 'audio_id': 'p225_007', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F01_p225_007.flac', 'array': array([-0.00494385, -0.00494385, -0.00488281, ..., -0.01208496,
#        -0.01199341, -0.01193237]), 'sampling_rate': 16000}, 'audio_id': 'p225_007', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p225_007.flac', 'array': array([ 0.00112915,  0.00125122,  0.00125122, ..., -0.00384521,
#        -0.00372314, -0.003479  ]), 'sampling_rate': 48000}, 'audio_id': 'p225_007', 'real_or_fake': 'F05'}
# {'audio': {'path': 'R_p225_007.flac', 'array': array([ 0.00189209,  0.00286865,  0.00244141, ..., -0.00463867,
#        -0.00494385, -0.00369263]), 'sampling_rate': 48000}, 'audio_id': 'p225_007', 'real_or_fake': 'R'}
# {'audio': {'path': 'F04_p225_007.flac', 'array': array([ 0.00204468,  0.0010376 ,  0.00125122, ..., -0.00311279,
#        -0.00311279, -0.00314331]), 'sampling_rate': 24000}, 'audio_id': 'p225_007', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p225_007.flac', 'array': array([ 0.0017395 ,  0.00164795,  0.00183105, ..., -0.00692749,
#        -0.00692749, -0.00674438]), 'sampling_rate': 16000}, 'audio_id': 'p225_007', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F03_p225_008.flac', 'array': array([0.00186157, 0.00204468, 0.00164795, ..., 0.00134277, 0.00054932,
#        0.00177002]), 'sampling_rate': 16000}, 'audio_id': 'p225_008', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p225_008.flac', 'array': array([0.00186157, 0.00091553, 0.00115967, ..., 0.00012207, 0.00012207,
#        0.00012207]), 'sampling_rate': 24000}, 'audio_id': 'p225_008', 'real_or_fake': 'F04'}
# {'audio': {'path': 'R_p225_008.flac', 'array': array([0.00408936, 0.00558472, 0.00491333, ..., 0.00012207, 0.00039673,
#        0.        ]), 'sampling_rate': 48000}, 'audio_id': 'p225_008', 'real_or_fake': 'R'}
# {'audio': {'path': 'F01_p225_008.flac', 'array': array([ 0.00180054,  0.0017395 ,  0.00177002, ..., -0.02142334,
#        -0.02890015, -0.03024292]), 'sampling_rate': 16000}, 'audio_id': 'p225_008', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p225_008.flac', 'array': array([ 0.00762939,  0.00756836,  0.00744629, ..., -0.00222778,
#        -0.00222778, -0.0020752 ]), 'sampling_rate': 48000}, 'audio_id': 'p225_008', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F02_p225_008.flac', 'array': array([ 3.05175781e-04,  3.66210938e-04,  3.96728516e-04, ...,
#         6.10351562e-05, -6.10351562e-05, -1.83105469e-04]), 'sampling_rate': 16000}, 'audio_id': 'p225_008', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p225_008.flac', 'array': array([0.00186157, 0.00204468, 0.00164795, ..., 0.00134277, 0.00054932,
#        0.00177002]), 'sampling_rate': 16000}, 'audio_id': 'p225_008', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F05_p225_010.flac', 'array': array([-0.0015564 , -0.0017395 , -0.00143433, ...,  0.00628662,
#         0.00592041,  0.00585938]), 'sampling_rate': 48000}, 'audio_id': 'p225_010', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p225_010.flac', 'array': array([ 0.0039978 ,  0.00405884,  0.00411987, ..., -0.00274658,
#        -0.00311279, -0.00338745]), 'sampling_rate': 16000}, 'audio_id': 'p225_010', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F06_p225_010.flac', 'array': array([ 0.00204468,  0.00167847,  0.00170898, ..., -0.01260376,
#        -0.01275635, -0.01254272]), 'sampling_rate': 16000}, 'audio_id': 'p225_010', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F02_p225_010.flac', 'array': array([-3.05175781e-05, -2.74658203e-04, -5.18798828e-04, ...,
#        -2.74658203e-04, -8.85009766e-04, -1.31225586e-03]), 'sampling_rate': 16000}, 'audio_id': 'p225_010', 'real_or_fake': 'F02'}
# {'audio': {'path': 'R_p225_010.flac', 'array': array([-0.00192261, -0.00247192, -0.00222778, ...,  0.00613403,
#         0.00646973,  0.00515747]), 'sampling_rate': 48000}, 'audio_id': 'p225_010', 'real_or_fake': 'R'}
# {'audio': {'path': 'F03_p225_010.flac', 'array': array([ 0.00204468,  0.00167847,  0.00170898, ..., -0.01260376,
#        -0.01275635, -0.01254272]), 'sampling_rate': 16000}, 'audio_id': 'p225_010', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p225_010.flac', 'array': array([ 3.05175781e-04, -6.10351562e-05,  1.52587891e-04, ...,
#         5.46264648e-03,  5.46264648e-03,  5.43212891e-03]), 'sampling_rate': 24000}, 'audio_id': 'p225_010', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F02_p225_011.flac', 'array': array([ 5.79833984e-04,  7.62939453e-04,  5.79833984e-04, ...,
#         6.71386719e-04, -3.05175781e-05,  2.44140625e-04]), 'sampling_rate': 16000}, 'audio_id': 'p225_011', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p225_011.flac', 'array': array([0.00094604, 0.00106812, 0.00119019, ..., 0.00238037, 0.00198364,
#        0.00231934]), 'sampling_rate': 16000}, 'audio_id': 'p225_011', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F01_p225_011.flac', 'array': array([0.00595093, 0.00610352, 0.00622559, ..., 0.16061401, 0.14611816,
#        0.13076782]), 'sampling_rate': 16000}, 'audio_id': 'p225_011', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p225_011.flac', 'array': array([-6.10351562e-05, -1.22070312e-04,  0.00000000e+00, ...,
#         4.11987305e-03,  4.63867188e-03,  4.36401367e-03]), 'sampling_rate': 48000}, 'audio_id': 'p225_011', 'real_or_fake': 'F05'}
# {'audio': {'path': 'R_p225_011.flac', 'array': array([-0.00024414,  0.00024414,  0.00024414, ...,  0.00878906,
#         0.00814819,  0.00897217]), 'sampling_rate': 48000}, 'audio_id': 'p225_011', 'real_or_fake': 'R'}
# {'audio': {'path': 'F04_p225_011.flac', 'array': array([0.00259399, 0.00146484, 0.00161743, ..., 0.00845337, 0.00848389,
#        0.00848389]), 'sampling_rate': 24000}, 'audio_id': 'p225_011', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p225_011.flac', 'array': array([0.00094604, 0.00106812, 0.00119019, ..., 0.00238037, 0.00198364,
#        0.00231934]), 'sampling_rate': 16000}, 'audio_id': 'p225_011', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p225_013.flac', 'array': array([ 0.00479126,  0.00299072,  0.00326538, ..., -0.00280762,
#        -0.00280762, -0.00289917]), 'sampling_rate': 24000}, 'audio_id': 'p225_013', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p225_013.flac', 'array': array([0.00195312, 0.0017395 , 0.00183105, ..., 0.00408936, 0.00421143,
#        0.00427246]), 'sampling_rate': 16000}, 'audio_id': 'p225_013', 'real_or_fake': 'F03'}
# {'audio': {'path': 'R_p225_013.flac', 'array': array([ 0.00689697,  0.00997925,  0.0088501 , ..., -0.0017395 ,
#        -0.00180054, -0.0017395 ]), 'sampling_rate': 48000}, 'audio_id': 'p225_013', 'real_or_fake': 'R'}
# {'audio': {'path': 'F06_p225_013.flac', 'array': array([0.00195312, 0.0017395 , 0.00183105, ..., 0.00408936, 0.00421143,
#        0.00427246]), 'sampling_rate': 16000}, 'audio_id': 'p225_013', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F02_p225_013.flac', 'array': array([-0.00048828, -0.00021362, -0.00018311, ...,  0.00112915,
#         0.00088501,  0.00061035]), 'sampling_rate': 16000}, 'audio_id': 'p225_013', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F05_p225_013.flac', 'array': array([ 0.00204468,  0.00201416,  0.00204468, ..., -0.00350952,
#        -0.00344849, -0.00326538]), 'sampling_rate': 48000}, 'audio_id': 'p225_013', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p225_013.flac', 'array': array([ 0.00662231,  0.00671387,  0.00683594, ..., -0.00250244,
#        -0.00393677, -0.00494385]), 'sampling_rate': 16000}, 'audio_id': 'p225_013', 'real_or_fake': 'F01'}
# {'audio': {'path': 'R_p225_014.flac', 'array': array([0.00280762, 0.00454712, 0.00390625, ..., 0.00204468, 0.00201416,
#        0.00244141]), 'sampling_rate': 48000}, 'audio_id': 'p225_014', 'real_or_fake': 'R'}
# {'audio': {'path': 'F03_p225_014.flac', 'array': array([0.00146484, 0.00167847, 0.00170898, ..., 0.00738525, 0.00750732,
#        0.00769043]), 'sampling_rate': 16000}, 'audio_id': 'p225_014', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p225_014.flac', 'array': array([ 0.00146484,  0.00048828,  0.00067139, ..., -0.00167847,
#        -0.00164795, -0.00170898]), 'sampling_rate': 24000}, 'audio_id': 'p225_014', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F01_p225_014.flac', 'array': array([-0.0032959 , -0.00332642, -0.00302124, ...,  0.00332642,
#         0.00326538,  0.00332642]), 'sampling_rate': 16000}, 'audio_id': 'p225_014', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p225_014.flac', 'array': array([0.00762939, 0.00756836, 0.00744629, ..., 0.00439453, 0.00476074,
#        0.00445557]), 'sampling_rate': 48000}, 'audio_id': 'p225_014', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F02_p225_014.flac', 'array': array([-1.52587891e-04, -3.66210938e-04, -7.32421875e-04, ...,
#         3.66210938e-04,  4.57763672e-04, -3.05175781e-05]), 'sampling_rate': 16000}, 'audio_id': 'p225_014', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p225_014.flac', 'array': array([0.00146484, 0.00167847, 0.00170898, ..., 0.00738525, 0.00750732,
#        0.00769043]), 'sampling_rate': 16000}, 'audio_id': 'p225_014', 'real_or_fake': 'F06'}
# Total time elapsed: 4.066211938858032 seconds

# %% [markdown]
# ### Stream multiple Audio files from Multiple Parquet files

# %%
def get_dataset(audio_ids):
    if isinstance(audio_ids, str):
        audio_ids = [audio_ids]

    # Create a dictionary to map parquet files to audio IDs
    parquet_to_audio_ids = defaultdict(list)
    for audio_id in audio_ids:
        parquet_file = audio_id_to_file_map[audio_id]['train']
        parquet_to_audio_ids[parquet_file].append(audio_id)

    # Create a generator to yield filtered examples from each parquet file
    def dataset_generator():
        for parquet_file, ids in parquet_to_audio_ids.items():
            iterable_ds = load_dataset("parquet", data_files={'train': parquet_file}, split="train", streaming=True)
            filtered_ds = iterable_ds.filter(lambda example: example['audio_id'] in ids)
            for example in filtered_ds:
                yield example

    return dataset_generator()

audio_ids = list(audio_id_to_file_map.keys())
random_audio_ids = random.sample(audio_ids, 10)

start_time = time.time()

dataset_gen = get_dataset(random_audio_ids)

# Iterate over the generator to process each example
for example in dataset_gen:
    print(example)

current_time = time.time()
print(f"Total time elapsed: {current_time - start_time} seconds")
# Out:
# {'audio': {'path': 'R_p236_083.flac', 'array': array([ 0.03491211,  0.04995728,  0.04464722, ..., -0.06677246,
#        -0.06228638, -0.06896973]), 'sampling_rate': 48000}, 'audio_id': 'p236_083', 'real_or_fake': 'R'}
# {'audio': {'path': 'F03_p236_083.flac', 'array': array([ 0.02581787,  0.02758789,  0.02987671, ..., -0.06774902,
#        -0.06851196, -0.06954956]), 'sampling_rate': 16000}, 'audio_id': 'p236_083', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p236_083.flac', 'array': array([0.03515625, 0.03408813, 0.03442383, ..., 0.03271484, 0.03311157,
#        0.03344727]), 'sampling_rate': 24000}, 'audio_id': 'p236_083', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F05_p236_083.flac', 'array': array([ 0.01300049,  0.00997925,  0.00726318, ..., -0.02612305,
#        -0.02603149, -0.02661133]), 'sampling_rate': 48000}, 'audio_id': 'p236_083', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p236_083.flac', 'array': array([ 0.0480957 ,  0.04959106,  0.05072021, ..., -0.01605225,
#        -0.01330566, -0.01004028]), 'sampling_rate': 16000}, 'audio_id': 'p236_083', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F06_p236_083.flac', 'array': array([ 0.02581787,  0.02758789,  0.02987671, ..., -0.06774902,
#        -0.06851196, -0.06954956]), 'sampling_rate': 16000}, 'audio_id': 'p236_083', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F02_p236_083.flac', 'array': array([0.00598145, 0.00921631, 0.01199341, ..., 0.003479  , 0.00411987,
#        0.00332642]), 'sampling_rate': 16000}, 'audio_id': 'p236_083', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F05_p261_318.flac', 'array': array([0.00112915, 0.00125122, 0.00125122, ..., 0.00601196, 0.00582886,
#        0.00576782]), 'sampling_rate': 48000}, 'audio_id': 'p261_318', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p261_318.flac', 'array': array([ 0.00549316,  0.00549316,  0.00534058, ..., -0.01123047,
#        -0.01147461, -0.01153564]), 'sampling_rate': 16000}, 'audio_id': 'p261_318', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F06_p261_318.flac', 'array': array([0.00460815, 0.00515747, 0.0057373 , ..., 0.00735474, 0.00723267,
#        0.00735474]), 'sampling_rate': 16000}, 'audio_id': 'p261_318', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F02_p261_318.flac', 'array': array([ 0.00012207,  0.00036621,  0.00039673, ...,  0.        ,
#        -0.00076294, -0.00183105]), 'sampling_rate': 16000}, 'audio_id': 'p261_318', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F03_p261_318.flac', 'array': array([0.00460815, 0.00515747, 0.0057373 , ..., 0.00735474, 0.00723267,
#        0.00735474]), 'sampling_rate': 16000}, 'audio_id': 'p261_318', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p261_318.flac', 'array': array([ 0.00161743,  0.00067139,  0.00094604, ..., -0.00305176,
#        -0.00305176, -0.00305176]), 'sampling_rate': 24000}, 'audio_id': 'p261_318', 'real_or_fake': 'F04'}
# {'audio': {'path': 'R_p261_318.flac', 'array': array([0.00210571, 0.00262451, 0.00271606, ..., 0.00463867, 0.00424194,
#        0.00485229]), 'sampling_rate': 48000}, 'audio_id': 'p261_318', 'real_or_fake': 'R'}
# {'audio': {'path': 'R_p261_399.flac', 'array': array([-0.0032959 , -0.00448608, -0.00384521, ...,  0.00244141,
#         0.00320435,  0.00204468]), 'sampling_rate': 48000}, 'audio_id': 'p261_399', 'real_or_fake': 'R'}
# {'audio': {'path': 'F04_p261_399.flac', 'array': array([-0.00192261, -0.00170898, -0.00161743, ..., -0.00119019,
#        -0.00119019, -0.0012207 ]), 'sampling_rate': 24000}, 'audio_id': 'p261_399', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p261_399.flac', 'array': array([0.00613403, 0.00579834, 0.00622559, ..., 0.02166748, 0.02191162,
#        0.02203369]), 'sampling_rate': 16000}, 'audio_id': 'p261_399', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F02_p261_399.flac', 'array': array([-0.00112915, -0.00149536, -0.00192261, ..., -0.00048828,
#        -0.0005188 , -0.00079346]), 'sampling_rate': 16000}, 'audio_id': 'p261_399', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p261_399.flac', 'array': array([0.00613403, 0.00579834, 0.00622559, ..., 0.02166748, 0.02191162,
#        0.02203369]), 'sampling_rate': 16000}, 'audio_id': 'p261_399', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F01_p261_399.flac', 'array': array([-0.00408936, -0.00387573, -0.00366211, ..., -0.00579834,
#        -0.00543213, -0.0043335 ]), 'sampling_rate': 16000}, 'audio_id': 'p261_399', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p261_399.flac', 'array': array([-0.0015564 , -0.0017395 , -0.00143433, ...,  0.00170898,
#         0.00164795,  0.00180054]), 'sampling_rate': 48000}, 'audio_id': 'p261_399', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F06_p334_038.flac', 'array': array([ 0.00421143,  0.00442505,  0.00430298, ..., -0.00982666,
#        -0.00912476, -0.00897217]), 'sampling_rate': 16000}, 'audio_id': 'p334_038', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F02_p334_038.flac', 'array': array([-1.80053711e-03, -1.95312500e-03, -2.25830078e-03, ...,
#         5.79833984e-04,  3.05175781e-04,  9.15527344e-05]), 'sampling_rate': 16000}, 'audio_id': 'p334_038', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F05_p334_038.flac', 'array': array([-0.00335693, -0.0032959 , -0.00320435, ...,  0.00219727,
#         0.00186157,  0.00183105]), 'sampling_rate': 48000}, 'audio_id': 'p334_038', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p334_038.flac', 'array': array([-0.00405884, -0.0039978 , -0.00387573, ...,  0.00280762,
#         0.00280762,  0.00314331]), 'sampling_rate': 16000}, 'audio_id': 'p334_038', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F04_p334_038.flac', 'array': array([-0.0010376 , -0.00106812, -0.00091553, ..., -0.00015259,
#        -0.00012207, -0.00015259]), 'sampling_rate': 24000}, 'audio_id': 'p334_038', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p334_038.flac', 'array': array([ 0.00421143,  0.00442505,  0.00430298, ..., -0.00982666,
#        -0.00912476, -0.00897217]), 'sampling_rate': 16000}, 'audio_id': 'p334_038', 'real_or_fake': 'F03'}
# {'audio': {'path': 'R_p334_038.flac', 'array': array([-0.00378418, -0.00598145, -0.00524902, ...,  0.00247192,
#         0.00253296,  0.00268555]), 'sampling_rate': 48000}, 'audio_id': 'p334_038', 'real_or_fake': 'R'}
# {'audio': {'path': 'F02_p247_336.flac', 'array': array([-0.00057983, -0.00079346, -0.00091553, ...,  0.00042725,
#         0.00027466, -0.00015259]), 'sampling_rate': 16000}, 'audio_id': 'p247_336', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p247_336.flac', 'array': array([0.00259399, 0.00286865, 0.00259399, ..., 0.00631714, 0.00695801,
#        0.00747681]), 'sampling_rate': 16000}, 'audio_id': 'p247_336', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F01_p247_336.flac', 'array': array([-4.91333008e-03, -4.91333008e-03, -4.94384766e-03, ...,
#         6.10351562e-05,  9.15527344e-05,  2.13623047e-04]), 'sampling_rate': 16000}, 'audio_id': 'p247_336', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p247_336.flac', 'array': array([ 0.00112915,  0.00125122,  0.00125122, ..., -0.00531006,
#        -0.00540161, -0.00564575]), 'sampling_rate': 48000}, 'audio_id': 'p247_336', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F04_p247_336.flac', 'array': array([ 0.00054932,  0.00012207,  0.00021362, ..., -0.0032959 ,
#        -0.0032959 , -0.0032959 ]), 'sampling_rate': 24000}, 'audio_id': 'p247_336', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p247_336.flac', 'array': array([0.00259399, 0.00286865, 0.00259399, ..., 0.00631714, 0.00695801,
#        0.00747681]), 'sampling_rate': 16000}, 'audio_id': 'p247_336', 'real_or_fake': 'F03'}
# {'audio': {'path': 'R_p247_336.flac', 'array': array([ 0.00039673,  0.00082397,  0.00042725, ..., -0.00570679,
#        -0.00643921, -0.00469971]), 'sampling_rate': 48000}, 'audio_id': 'p247_336', 'real_or_fake': 'R'}
# {'audio': {'path': 'F03_p283_090.flac', 'array': array([0.00357056, 0.00372314, 0.00415039, ..., 0.01202393, 0.01187134,
#        0.01187134]), 'sampling_rate': 16000}, 'audio_id': 'p283_090', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p283_090.flac', 'array': array([-0.0012207 , -0.00112915, -0.00112915, ...,  0.00466919,
#         0.00469971,  0.00463867]), 'sampling_rate': 24000}, 'audio_id': 'p283_090', 'real_or_fake': 'F04'}
# {'audio': {'path': 'R_p283_090.flac', 'array': array([-0.00439453, -0.00650024, -0.00561523, ...,  0.00592041,
#         0.00698853,  0.00418091]), 'sampling_rate': 48000}, 'audio_id': 'p283_090', 'real_or_fake': 'R'}
# {'audio': {'path': 'F01_p283_090.flac', 'array': array([-0.00112915, -0.00119019, -0.00128174, ...,  0.00839233,
#        -0.00915527,  0.01876831]), 'sampling_rate': 16000}, 'audio_id': 'p283_090', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p283_090.flac', 'array': array([-0.00335693, -0.0032959 , -0.00320435, ...,  0.01177979,
#         0.01156616,  0.01187134]), 'sampling_rate': 48000}, 'audio_id': 'p283_090', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F02_p283_090.flac', 'array': array([-0.00146484, -0.00152588, -0.00186157, ..., -0.00219727,
#        -0.00265503, -0.00335693]), 'sampling_rate': 16000}, 'audio_id': 'p283_090', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p283_090.flac', 'array': array([0.00357056, 0.00372314, 0.00415039, ..., 0.01202393, 0.01187134,
#        0.01187134]), 'sampling_rate': 16000}, 'audio_id': 'p283_090', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F04_p260_242.flac', 'array': array([ 0.00164795,  0.00076294,  0.00094604, ..., -0.00891113,
#        -0.00888062, -0.00891113]), 'sampling_rate': 24000}, 'audio_id': 'p260_242', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F03_p260_242.flac', 'array': array([0.00140381, 0.00186157, 0.0020752 , ..., 0.00186157, 0.00180054,
#        0.00189209]), 'sampling_rate': 16000}, 'audio_id': 'p260_242', 'real_or_fake': 'F03'}
# {'audio': {'path': 'R_p260_242.flac', 'array': array([0.0007019 , 0.00097656, 0.00073242, ..., 0.00906372, 0.01028442,
#        0.00683594]), 'sampling_rate': 48000}, 'audio_id': 'p260_242', 'real_or_fake': 'R'}
# {'audio': {'path': 'F06_p260_242.flac', 'array': array([0.00140381, 0.00186157, 0.0020752 , ..., 0.00186157, 0.00180054,
#        0.00189209]), 'sampling_rate': 16000}, 'audio_id': 'p260_242', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F02_p260_242.flac', 'array': array([-0.00015259, -0.00030518, -0.00042725, ..., -0.00354004,
#        -0.00378418, -0.00369263]), 'sampling_rate': 16000}, 'audio_id': 'p260_242', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F05_p260_242.flac', 'array': array([0.00112915, 0.00125122, 0.00125122, ..., 0.00610352, 0.00622559,
#        0.00637817]), 'sampling_rate': 48000}, 'audio_id': 'p260_242', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p260_242.flac', 'array': array([0.0032959 , 0.00332642, 0.0032959 , ..., 0.01516724, 0.01394653,
#        0.01486206]), 'sampling_rate': 16000}, 'audio_id': 'p260_242', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F03_p308_297.flac', 'array': array([0.00723267, 0.00680542, 0.00674438, ..., 0.03051758, 0.02987671,
#        0.03015137]), 'sampling_rate': 16000}, 'audio_id': 'p308_297', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p308_297.flac', 'array': array([0.00311279, 0.00177002, 0.00198364, ..., 0.00305176, 0.00305176,
#        0.00305176]), 'sampling_rate': 24000}, 'audio_id': 'p308_297', 'real_or_fake': 'F04'}
# {'audio': {'path': 'R_p308_297.flac', 'array': array([0.0022583 , 0.00302124, 0.00271606, ..., 0.00115967, 0.00082397,
#        0.0010376 ]), 'sampling_rate': 48000}, 'audio_id': 'p308_297', 'real_or_fake': 'R'}
# {'audio': {'path': 'F05_p308_297.flac', 'array': array([0.00112915, 0.00125122, 0.00125122, ..., 0.0020752 , 0.00167847,
#        0.00186157]), 'sampling_rate': 48000}, 'audio_id': 'p308_297', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F01_p308_297.flac', 'array': array([-0.00473022, -0.00469971, -0.00463867, ..., -0.0027771 ,
#        -0.00280762, -0.00283813]), 'sampling_rate': 16000}, 'audio_id': 'p308_297', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F06_p308_297.flac', 'array': array([0.00723267, 0.00680542, 0.00674438, ..., 0.03051758, 0.02987671,
#        0.03015137]), 'sampling_rate': 16000}, 'audio_id': 'p308_297', 'real_or_fake': 'F06'}
# {'audio': {'path': 'F02_p308_297.flac', 'array': array([ 0.00231934,  0.00244141,  0.0022583 , ..., -0.00039673,
#        -0.00057983, -0.00100708]), 'sampling_rate': 16000}, 'audio_id': 'p308_297', 'real_or_fake': 'F02'}
# {'audio': {'path': 'R_p275_152.flac', 'array': array([-0.00375366, -0.00552368, -0.00506592, ..., -0.00619507,
#        -0.00579834, -0.00640869]), 'sampling_rate': 48000}, 'audio_id': 'p275_152', 'real_or_fake': 'R'}
# {'audio': {'path': 'F03_p275_152.flac', 'array': array([ 0.00271606,  0.00280762,  0.00262451, ..., -0.00134277,
#        -0.00100708, -0.00085449]), 'sampling_rate': 16000}, 'audio_id': 'p275_152', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p275_152.flac', 'array': array([-0.0032959 , -0.00289917, -0.00286865, ..., -0.00756836,
#        -0.00753784, -0.00750732]), 'sampling_rate': 24000}, 'audio_id': 'p275_152', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F01_p275_152.flac', 'array': array([ 0.0017395 ,  0.00189209,  0.00219727, ..., -0.01132202,
#        -0.00808716, -0.00027466]), 'sampling_rate': 16000}, 'audio_id': 'p275_152', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p275_152.flac', 'array': array([-0.00335693, -0.0032959 , -0.00320435, ..., -0.00708008,
#        -0.00744629, -0.0071106 ]), 'sampling_rate': 48000}, 'audio_id': 'p275_152', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F02_p275_152.flac', 'array': array([-1.25122070e-03, -1.09863281e-03, -1.09863281e-03, ...,
#         4.57763672e-04,  1.52587891e-04, -6.10351562e-05]), 'sampling_rate': 16000}, 'audio_id': 'p275_152', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p275_152.flac', 'array': array([ 0.00271606,  0.00280762,  0.00262451, ..., -0.00134277,
#        -0.00100708, -0.00085449]), 'sampling_rate': 16000}, 'audio_id': 'p275_152', 'real_or_fake': 'F06'}
# {'audio': {'path': 'R_p335_105.flac', 'array': array([0.00296021, 0.00408936, 0.00387573, ..., 0.00878906, 0.01004028,
#        0.00704956]), 'sampling_rate': 48000}, 'audio_id': 'p335_105', 'real_or_fake': 'R'}
# {'audio': {'path': 'F03_p335_105.flac', 'array': array([0.00189209, 0.00152588, 0.00167847, ..., 0.00762939, 0.00778198,
#        0.00772095]), 'sampling_rate': 16000}, 'audio_id': 'p335_105', 'real_or_fake': 'F03'}
# {'audio': {'path': 'F04_p335_105.flac', 'array': array([0.0027771 , 0.00146484, 0.00161743, ..., 0.00802612, 0.00805664,
#        0.00805664]), 'sampling_rate': 24000}, 'audio_id': 'p335_105', 'real_or_fake': 'F04'}
# {'audio': {'path': 'F01_p335_105.flac', 'array': array([-0.00695801, -0.00695801, -0.00686646, ..., -0.00378418,
#        -0.00384521, -0.00390625]), 'sampling_rate': 16000}, 'audio_id': 'p335_105', 'real_or_fake': 'F01'}
# {'audio': {'path': 'F05_p335_105.flac', 'array': array([0.00762939, 0.00756836, 0.00744629, ..., 0.00796509, 0.00814819,
#        0.00805664]), 'sampling_rate': 48000}, 'audio_id': 'p335_105', 'real_or_fake': 'F05'}
# {'audio': {'path': 'F02_p335_105.flac', 'array': array([ 0.00048828,  0.00082397,  0.00082397, ..., -0.00180054,
#        -0.00152588, -0.00204468]), 'sampling_rate': 16000}, 'audio_id': 'p335_105', 'real_or_fake': 'F02'}
# {'audio': {'path': 'F06_p335_105.flac', 'array': array([0.00189209, 0.00152588, 0.00167847, ..., 0.00762939, 0.00778198,
#        0.00772095]), 'sampling_rate': 16000}, 'audio_id': 'p335_105', 'real_or_fake': 'F06'}
# Total time elapsed: 36.045565605163574 seconds
