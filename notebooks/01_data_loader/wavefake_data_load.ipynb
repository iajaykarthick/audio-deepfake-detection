# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Using helper functions in src/data/load/data_loader

# %%
import random
from data.load.data_loader import get_wavefake_audio_id_list, load_audio_data

# %%
audio_ids = get_wavefake_audio_id_list()
len(audio_ids)
# Out:
# 13100

# %%
# It won't download the data to local disk. Instead, it streams the data directly from HuggingFace,
# holding only one sample in memory at each iteration.

random_audio_ids = random.sample(audio_ids, 5)
iterable_dataset = load_audio_data(
    audio_ids=random_audio_ids,
    dataset='wavefake'
)

for sample in iterable_dataset:
    print(sample)
# Out:
# {'audio': {'path': 'LJ022-0185_gen.wav', 'array': array([0.00091553, 0.00100708, 0.00100708, ..., 0.00082397, 0.00082397,
#        0.00079346]), 'sampling_rate': 22050}, 'audio_id': 'LJ022-0185', 'real_or_fake': 'WF1'}
# {'audio': {'path': 'LJ022-0185_gen.wav', 'array': array([-2.47192383e-03, -2.62451172e-03, -2.59399414e-03, ...,
#        -1.52587891e-04, -6.10351562e-05,  3.35693359e-04]), 'sampling_rate': 22050}, 'audio_id': 'LJ022-0185', 'real_or_fake': 'WF2'}
# {'audio': {'path': 'LJ022-0185_generated.wav', 'array': array([-0.00064087, -0.00036621, -0.00033569, ..., -0.00061035,
#        -0.00054932, -0.00018311]), 'sampling_rate': 22050}, 'audio_id': 'LJ022-0185', 'real_or_fake': 'WF3'}
# {'audio': {'path': 'LJ022-0185_gen.wav', 'array': array([-0.00698853, -0.00689697, -0.00686646, ..., -0.00057983,
#        -0.0007019 , -0.00067139]), 'sampling_rate': 22050}, 'audio_id': 'LJ022-0185', 'real_or_fake': 'WF4'}
# {'audio': {'path': 'LJ022-0185_gen.wav', 'array': array([-6.40869141e-04, -6.10351562e-04, -5.18798828e-04, ...,
#        -3.05175781e-05,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 22050}, 'audio_id': 'LJ022-0185', 'real_or_fake': 'WF5'}
# {'audio': {'path': 'LJ022-0185_gen.wav', 'array': array([-0.00335693, -0.00234985, -0.00204468, ..., -0.00024414,
#         0.00012207,  0.        ]), 'sampling_rate': 22050}, 'audio_id': 'LJ022-0185', 'real_or_fake': 'WF6'}
# {'audio': {'path': 'LJ022-0185.wav', 'array': array([9.15527344e-05, 1.52587891e-04, 2.74658203e-04, ...,
#        3.05175781e-05, 1.22070312e-04, 4.27246094e-04]), 'sampling_rate': 22050}, 'audio_id': 'LJ022-0185', 'real_or_fake': 'WF7'}
# {'audio': {'path': 'LJ022-0185.wav', 'array': array([ 3.05175781e-05,  1.22070312e-04,  9.15527344e-05, ...,
#         2.13623047e-04, -3.05175781e-05, -1.83105469e-04]), 'sampling_rate': 22050}, 'audio_id': 'LJ022-0185', 'real_or_fake': 'R'}
# {'audio': {'path': 'LJ048-0081_gen.wav', 'array': array([-0.00061035, -0.00247192, -0.00601196, ...,  0.00091553,
#         0.00094604,  0.00091553]), 'sampling_rate': 22050}, 'audio_id': 'LJ048-0081', 'real_or_fake': 'WF1'}
# {'audio': {'path': 'LJ048-0081_gen.wav', 'array': array([-7.32421875e-04, -2.50244141e-03, -1.95312500e-03, ...,
#         6.10351562e-05,  3.35693359e-04,  6.71386719e-04]), 'sampling_rate': 22050}, 'audio_id': 'LJ048-0081', 'real_or_fake': 'WF2'}
# {'audio': {'path': 'LJ048-0081_generated.wav', 'array': array([-0.00146484, -0.0020752 , -0.00042725, ...,  0.00054932,
#         0.00061035,  0.00042725]), 'sampling_rate': 22050}, 'audio_id': 'LJ048-0081', 'real_or_fake': 'WF3'}
# {'audio': {'path': 'LJ048-0081_gen.wav', 'array': array([-1.37329102e-03, -1.37329102e-03, -2.50244141e-03, ...,
#        -6.10351562e-05, -1.52587891e-04, -9.15527344e-05]), 'sampling_rate': 22050}, 'audio_id': 'LJ048-0081', 'real_or_fake': 'WF4'}
# {'audio': {'path': 'LJ048-0081_gen.wav', 'array': array([ 9.15527344e-04,  6.40869141e-04, -1.25122070e-03, ...,
#        -3.05175781e-05,  0.00000000e+00,  0.00000000e+00]), 'sampling_rate': 22050}, 'audio_id': 'LJ048-0081', 'real_or_fake': 'WF5'}
# {'audio': {'path': 'LJ048-0081_gen.wav', 'array': array([-0.00790405, -0.00604248, -0.00744629, ..., -0.00067139,
#        -0.00036621, -0.00091553]), 'sampling_rate': 22050}, 'audio_id': 'LJ048-0081', 'real_or_fake': 'WF6'}
# {'audio': {'path': 'LJ048-0081.wav', 'array': array([0.00222778, 0.00158691, 0.00161743, ..., 0.00033569, 0.00015259,
#        0.00057983]), 'sampling_rate': 22050}, 'audio_id': 'LJ048-0081', 'real_or_fake': 'WF7'}
# {'audio': {'path': 'LJ048-0081.wav', 'array': array([ 6.10351562e-05,  0.00000000e+00,  6.10351562e-05, ...,
#        -1.52587891e-04, -1.22070312e-04,  0.00000000e+00]), 'sampling_rate': 22050}, 'audio_id': 'LJ048-0081', 'real_or_fake': 'R'}
# {'audio': {'path': 'LJ040-0109_gen.wav', 'array': array([0.00030518, 0.00027466, 0.00027466, ..., 0.00076294, 0.00082397,
#        0.00094604]), 'sampling_rate': 22050}, 'audio_id': 'LJ040-0109', 'real_or_fake': 'WF1'}
# {'audio': {'path': 'LJ
-03]), 'sampling_rate': 22050}, 'audio_id': 'LJ025-0085', 'real_or_fake': 'WF6'}
# {'audio': {'path': 'LJ025-0085.wav', 'array': array([-2.10571289e-03, -3.05175781e-05,  1.37329102e-03, ...,
#        -4.27246094e-04, -9.15527344e-05,  4.88281250e-04]), 'sampling_rate': 22050}, 'audio_id': 'LJ025-0085', 'real_or_fake': 'WF7'}
# {'audio': {'path': 'LJ025-0085.wav', 'array': array([ 1.83105469e-04,  3.05175781e-04,  3.66210938e-04, ...,
#        -2.13623047e-04, -9.15527344e-05,  1.83105469e-04]), 'sampling_rate': 22050}, 'audio_id': 'LJ025-0085', 'real_or_fake': 'R'}

# %% [markdown]
# ### Code to load codecfake data from HuggingFace (without helper functions in src module)

# %%
import os
import time
import random

import json
import requests

import numpy as np
import matplotlib.pyplot as plt

import librosa

from datasets import load_dataset, Audio
from collections import defaultdict

# %%
from utils.config import load_config

config      = load_config()
cache_files = config['data_paths']['wavefake']['cache_files']

# %%
username      = "ajaykarthick"
dataset_name  = "wavefake-audio"
repo_id       = f"{username}/{dataset_name}"
json_file_url = f"https://huggingface.co/datasets/{repo_id}/resolve/main/audio_id_to_file_map.json"

# %%
# Get the Audio ID to Parquet File Map
response = requests.get(json_file_url)
response.raise_for_status()
audio_id_to_file_map = response.json()

# %% [markdown]
# ### Stream from HuggingFace Datasets (without Downloading datasets)

# %%
def get_dataset(audio_id):
    parquet_file = audio_id_to_file_map[audio_id]
    iterable_ds = load_dataset("parquet", data_files=parquet_file, split="train", streaming=True)
    dataset = iterable_ds.filter(lambda example: example['audio_id'] == audio_id)
    return dataset

audio_ids = list(audio_id_to_file_map.keys())
audio_id = audio_ids[-1]

start_time = time.time()

for example in get_dataset(audio_id):
    print(example)
    
current_time = time.time()
print(f"Time elapsed: {current_time - start_time} seconds")
# Out:
# {'audio': {'path': 'LJ050-0278_gen.wav', 'array': array([0.00048828, 0.00027466, 0.        , ..., 0.0010376 , 0.00112915,
#        0.0012207 ]), 'sampling_rate': 22050}, 'audio_id': 'LJ050-0278', 'real_or_fake': 'WF1'}
# {'audio': {'path': 'LJ050-0278_gen.wav', 'array': array([-0.00048828, -0.0005188 , -0.00039673, ...,  0.00064087,
#         0.00128174,  0.00216675]), 'sampling_rate': 22050}, 'audio_id': 'LJ050-0278', 'real_or_fake': 'WF2'}
# {'audio': {'path': 'LJ050-0278_generated.wav', 'array': array([-0.00042725,  0.00030518, -0.00042725, ..., -0.00018311,
#        -0.00036621, -0.00024414]), 'sampling_rate': 22050}, 'audio_id': 'LJ050-0278', 'real_or_fake': 'WF3'}
# {'audio': {'path': 'LJ050-0278_gen.wav', 'array': array([-2.16674805e-03, -2.16674805e-03, -2.19726562e-03, ...,
#         1.52587891e-04,  3.05175781e-05,  9.15527344e-05]), 'sampling_rate': 22050}, 'audio_id': 'LJ050-0278', 'real_or_fake': 'WF4'}
# {'audio': {'path': 'LJ050-0278_gen.wav', 'array': array([ 6.40869141e-04,  7.93457031e-04,  1.28173828e-03, ...,
#        -3.05175781e-04, -6.10351562e-05,  1.22070312e-04]), 'sampling_rate': 22050}, 'audio_id': 'LJ050-0278', 'real_or_fake': 'WF5'}
# {'audio': {'path': 'LJ050-0278_gen.wav', 'array': array([-4.57763672e-04, -1.03759766e-03, -1.70898438e-03, ...,
#        -3.05175781e-05,  9.76562500e-04,  1.19018555e-03]), 'sampling_rate': 22050}, 'audio_id': 'LJ050-0278', 'real_or_fake': 'WF6'}
# {'audio': {'path': 'LJ050-0278.wav', 'array': array([0.00180054, 0.00161743, 0.00161743, ..., 0.00048828, 0.00027466,
#        0.00024414]), 'sampling_rate': 22050}, 'audio_id': 'LJ050-0278', 'real_or_fake': 'WF7'}
# {'audio': {'path': 'LJ050-0278.wav', 'array': array([ 6.10351562e-05,  6.10351562e-05,  1.52587891e-04, ...,
#        -3.96728516e-04, -5.18798828e-04, -5.18798828e-04]), 'sampling_rate': 22050}, 'audio_id': 'LJ050-0278', 'real_or_fake': 'R'}
# Time elapsed: 13.365150928497314 seconds

# %% [markdown]
# ### Stream more than one audio ID from single parquet file

# %%
from datasets import load_dataset

def get_dataset(audio_ids):
    if isinstance(audio_ids, str):
        audio_ids = [audio_ids]

    # Check if all audio_ids belong to the same parquet file
    parquet_file = audio_id_to_file_map[audio_ids[0]]
    for audio_id in audio_ids:
        if audio_id_to_file_map[audio_id] != parquet_file:
            raise ValueError("Not all audio_ids belong to the same parquet file")

    iterable_ds = load_dataset("parquet", data_files=parquet_file, split="train", streaming=True)
    
    # Filter the dataset to include only the desired audio_ids
    dataset = iterable_ds.filter(lambda example: example['audio_id'] in audio_ids)
    return dataset


audio_ids = list(audio_id_to_file_map.keys())[:10] 

start_time = time.time()

dataset = get_dataset(audio_ids)
for example in dataset:
    print(example)

current_time = time.time()
print(f"Total time elapsed: {current_time - start_time} seconds")
# Out:
# {'audio': {'path': 'LJ001-0001_gen.wav', 'array': array([-9.15527344e-05, -9.15527344e-05, -9.15527344e-05, ...,
#         7.01904297e-04,  9.46044922e-04,  1.00708008e-03]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0001', 'real_or_fake': 'WF1'}
# {'audio': {'path': 'LJ001-0001_gen.wav', 'array': array([ 0.00097656,  0.00091553,  0.00100708, ..., -0.00042725,
#         0.00030518,  0.00073242]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0001', 'real_or_fake': 'WF2'}
# {'audio': {'path': 'LJ001-0001_generated.wav', 'array': array([ 0.00073242,  0.00067139, -0.00018311, ...,  0.00061035,
#         0.00045776,  0.00039673]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0001', 'real_or_fake': 'WF3'}
# {'audio': {'path': 'LJ001-0001_gen.wav', 'array': array([-0.00024414, -0.00021362, -0.00021362, ...,  0.00042725,
#         0.00042725,  0.00057983]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0001', 'real_or_fake': 'WF4'}
# {'audio': {'path': 'LJ001-0001_gen.wav', 'array': array([-9.15527344e-05, -1.52587891e-04, -1.22070312e-04, ...,
#         6.10351562e-05,  0.00000000e+00, -6.10351562e-05]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0001', 'real_or_fake': 'WF5'}
# {'audio': {'path': 'LJ001-0001_gen.wav', 'array': array([-0.00262451, -0.00213623, -0.00170898, ..., -0.00369263,
#        -0.00341797, -0.003479  ]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0001', 'real_or_fake': 'WF6'}
# {'audio': {'path': 'LJ001-0001.wav', 'array': array([-2.44140625e-04, -1.83105469e-04, -9.15527344e-05, ...,
#         6.71386719e-04,  5.18798828e-04,  1.83105469e-04]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0001', 'real_or_fake': 'WF7'}
# {'audio': {'path': 'LJ001-0001.wav', 'array': array([-7.32421875e-04, -7.62939453e-04, -6.40869141e-04, ...,
#         7.32421875e-04,  2.13623047e-04,  6.10351562e-05]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0001', 'real_or_fake': 'R'}
# {'audio': {'path': 'LJ001-0002_gen.wav', 'array': array([0.00112915, 0.00106812, 0.00085449, ..., 0.00088501, 0.00091553,
#        0.00091553]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0002', 'real_or_fake': 'WF1'}
# {'audio': {'path': 'LJ001-0002_gen.wav', 'array': array([-0.0010376 , -0.00094604, -0.00076294, ..., -0.00057983,
#        -0.00021362,  0.00018311]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0002', 'real_or_fake': 'WF2'}
# {'audio': {'path': 'LJ001-0002_generated.wav', 'array': array([ 0.0010376 ,  0.0015564 ,  0.00131226, ..., -0.00082397,
#        -0.00067139, -0.00036621]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0002', 'real_or_fake': 'WF3'}
# {'audio': {'path': 'LJ001-0002_gen.wav', 'array': array([-7.65991211e-03, -7.59887695e-03, -7.44628906e-03, ...,
#         1.83105469e-04,  9.15527344e-05,  2.44140625e-04]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0002', 'real_or_fake': 'WF4'}
# {'audio': {'path': 'LJ001-0002_gen.wav', 'array': array([ 4.57763672e-04,  3.66210938e-04,  8.23974609e-04, ...,
#        -1.22070312e-04,  0.00000000e+00,  3.05175781e-05]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0002', 'real_or_fake': 'WF5'}
# {'audio': {'path': 'LJ001-0002_gen.wav', 'array': array([-0.00323486, -0.00299072, -0.00338745, ..., -0.00167847,
#        -0.00158691, -0.00112915]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0002', 'real_or_fake': 'WF6'}
# {'audio': {'path': 'LJ001-0002.wav', 'array': array([-0.00082397, -0.00033569, -0.00030518, ...,  0.0007019 ,
#         0.00033569,  0.00033569]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0002', 'real_or_fake': 'WF7'}
# {'audio': {'path': 'LJ001-0002.wav', 'array': array([-0.00027466,  0.        ,  0.        , ..., -0.00088501,
#        -0.00097656, -0.00109863]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0002', 'real_or_fake': 'R'}
# {'audio': {'path': 'LJ001-
-03]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0010', 'real_or_fake': 'WF7'}
# {'audio': {'path': 'LJ001-0010.wav', 'array': array([-0.0007019 , -0.00064087, -0.00067139, ..., -0.00073242,
#        -0.00149536, -0.00234985]), 'sampling_rate': 22050}, 'audio_id': 'LJ001-0010', 'real_or_fake': 'R'}
# Total time elapsed: 12.488763332366943 seconds

# %% [markdown]
# ### Stream multiple Audio files from Multiple Parquet files

# %%
def get_dataset(audio_ids):
    if isinstance(audio_ids, str):
        audio_ids = [audio_ids]

    # Create a dictionary to map parquet files to audio IDs
    parquet_to_audio_ids = defaultdict(list)
    for audio_id in audio_ids:
        parquet_file = audio_id_to_file_map[audio_id]['train']
        parquet_to_audio_ids[parquet_file].append(audio_id)

    # Create a generator to yield filtered examples from each parquet file
    def dataset_generator():
        for parquet_file, ids in parquet_to_audio_ids.items():
            iterable_ds = load_dataset("parquet", data_files={'train': parquet_file}, split="train", streaming=True)
            filtered_ds = iterable_ds.filter(lambda example: example['audio_id'] in ids)
            for example in filtered_ds:
                yield example

    return dataset_generator()

audio_ids = list(audio_id_to_file_map.keys())
random_audio_ids = random.sample(audio_ids, 10)

start_time = time.time()

dataset_gen = get_dataset(random_audio_ids)

# Iterate over the generator to process each example
for example in dataset_gen:
    print(example)

current_time = time.time()
print(f"Total time elapsed: {current_time - start_time} seconds")
# Out:
# {'audio': {'path': 'LJ003-0317_gen.wav', 'array': array([9.15527344e-05, 3.05175781e-05, 3.05175781e-05, ...,
#        1.06811523e-03, 1.06811523e-03, 1.09863281e-03]), 'sampling_rate': 22050}, 'audio_id': 'LJ003-0317', 'real_or_fake': 'WF1'}
# {'audio': {'path': 'LJ003-0317_gen.wav', 'array': array([0.00018311, 0.00015259, 0.00018311, ..., 0.00033569, 0.00048828,
#        0.00085449]), 'sampling_rate': 22050}, 'audio_id': 'LJ003-0317', 'real_or_fake': 'WF2'}
# {'audio': {'path': 'LJ003-0317_generated.wav', 'array': array([-6.40869141e-04, -4.27246094e-04, -9.15527344e-05, ...,
#        -1.09863281e-03, -1.25122070e-03, -1.25122070e-03]), 'sampling_rate': 22050}, 'audio_id': 'LJ003-0317', 'real_or_fake': 'WF3'}
# {'audio': {'path': 'LJ003-0317_gen.wav', 'array': array([-0.0010376 , -0.00097656, -0.0010376 , ...,  0.00030518,
#         0.00021362,  0.00030518]), 'sampling_rate': 22050}, 'audio_id': 'LJ003-0317', 'real_or_fake': 'WF4'}
# {'audio': {'path': 'LJ003-0317_gen.wav', 'array': array([ 9.15527344e-05,  3.05175781e-05,  2.74658203e-04, ...,
#        -1.52587891e-04, -6.10351562e-05,  0.00000000e+00]), 'sampling_rate': 22050}, 'audio_id': 'LJ003-0317', 'real_or_fake': 'WF5'}
# {'audio': {'path': 'LJ003-0317_gen.wav', 'array': array([-0.00158691, -0.00131226, -0.00244141, ..., -0.00247192,
#        -0.00195312, -0.00198364]), 'sampling_rate': 22050}, 'audio_id': 'LJ003-0317', 'real_or_fake': 'WF6'}
# {'audio': {'path': 'LJ003-0317.wav', 'array': array([-0.00125122, -0.00115967, -0.00112915, ...,  0.00054932,
#         0.00054932,  0.00100708]), 'sampling_rate': 22050}, 'audio_id': 'LJ003-0317', 'real_or_fake': 'WF7'}
# {'audio': {'path': 'LJ003-0317.wav', 'array': array([ 0.00012207,  0.00027466,  0.00021362, ..., -0.00045776,
#        -0.0005188 , -0.00039673]), 'sampling_rate': 22050}, 'audio_id': 'LJ003-0317', 'real_or_fake': 'R'}
# {'audio': {'path': 'LJ014-0246_gen.wav', 'array': array([-0.00100708, -0.00100708, -0.00097656, ...,  0.00094604,
#         0.00100708,  0.00100708]), 'sampling_rate': 22050}, 'audio_id': 'LJ014-0246', 'real_or_fake': 'WF1'}
# {'audio': {'path': 'LJ014-0246_gen.wav', 'array': array([ 0.00054932,  0.00030518,  0.00042725, ..., -0.00030518,
#         0.        ,  0.00048828]), 'sampling_rate': 22050}, 'audio_id': 'LJ014-0246', 'real_or_fake': 'WF2'}
# {'audio': {'path': 'LJ014-0246_generated.wav', 'array': array([-0.00085449, -0.00064087, -0.00039673, ..., -0.00079346,
#        -0.0007019 , -0.00033569]), 'sampling_rate': 22050}, 'audio_id': 'LJ014-0246', 'real_or_fake': 'WF3'}
# {'audio': {'path': 'LJ014-0246_gen.wav', 'array': array([-0.00289917, -0.00286865, -0.00289917, ..., -0.00143433,
#        -0.0015564 , -0.00134277]), 'sampling_rate': 22050}, 'audio_id': 'LJ014-0246', 'real_or_fake': 'WF4'}
# {'audio': {'path': 'LJ014-0246_gen.wav', 'array': array([ 6.10351562e-05, -6.10351562e-05,  1.22070312e-04, ...,
#        -9.15527344e-05,  3.05175781e-05,  6.10351562e-05]), 'sampling_rate': 22050}, 'audio_id': 'LJ014-0246', 'real_or_fake': 'WF5'}
# {'audio': {'path': 'LJ014-0246_gen.wav', 'array': array([-0.00521851, -0.00488281, -0.00512695, ...,  0.00045776,
#         0.00024414,  0.        ]), 'sampling_rate': 22050}, 'audio_id': 'LJ014-0246', 'real_or_fake': 'WF6'}
# {'audio': {'path': 'LJ
), 'sampling_rate': 22050}, 'audio_id': 'LJ010-0024', 'real_or_fake': 'WF7'}
# {'audio': {'path': 'LJ010-0024.wav', 'array': array([0.00057983, 0.00073242, 0.0007019 , ..., 0.00036621, 0.00036621,
#        0.00082397]), 'sampling_rate': 22050}, 'audio_id': 'LJ010-0024', 'real_or_fake': 'R'}
# {'audio': {'path': 'LJ019-0046_gen.wav', 'array': array([0.00042725, 0.00039673, 0.00030518, ..., 0.00067139, 0.00073242,
#        0.0007019 ]), 'sampling_rate': 22050}, 'audio_id': 'LJ019-0046', 'real_or_fake': 'WF1'}
# {'audio': {'path': 'LJ019-0046_gen.wav', 'array': array([ 0.00000000e+00, -6.10351562e-05, -1.52587891e-04, ...,
#         0.00000000e+00,  3.35693359e-04,  6.71386719e-04]), 'sampling_rate': 22050}, 'audio_id': 'LJ019-0046', 'real_or_fake': 'WF2'}
# {'audio': {'path': 'LJ019-0046_generated.wav', 'array': array([-0.00082397, -0.00094604, -0.00119019, ...,  0.00018311,
#         0.00015259,  0.00027466]), 'sampling_rate': 22050}, 'audio_id': 'LJ019-0046', 'real_or_fake': 'WF3'}
# {'audio': {'path': 'LJ019-0046_gen.wav', 'array': array([-0.00338745, -0.00335693, -0.00335693, ..., -0.00115967,
#        -0.00128174, -0.00112915]), 'sampling_rate': 22050}, 'audio_id': 'LJ019-0046', 'real_or_fake': 'WF4'}
# {'audio': {'path': 'LJ019-0046_gen.wav', 'array': array([-2.44140625e-04, -4.57763672e-04, -3.66210938e-04, ...,
#        -6.10351562e-05,  3.05175781e-05,  6.10351562e-05]), 'sampling_rate': 22050}, 'audio_id': 'LJ019-0046', 'real_or_fake': 'WF5'}
# {'audio': {'path': 'LJ019-0046_gen.wav', 'array': array([-0.00476074, -0.00384521, -0.00430298, ..., -0.00030518,
#        -0.00015259, -0.00039673]), 'sampling_rate': 22050}, 'audio_id': 'LJ019-0046', 'real_or_fake': 'WF6'}
# {'audio': {'path': 'LJ019-0046.wav', 'array': array([ 4.57763672e-04,  3.35693359e-04,  1.83105469e-04, ...,
#        -3.05175781e-05, -9.15527344e-05,  2.13623047e-04]), 'sampling_rate': 22050}, 'audio_id': 'LJ019-0046', 'real_or_fake': 'WF7'}
# {'audio': {'path': 'LJ019-0046.wav', 'array': array([0.00039673, 0.00036621, 0.00030518, ..., 0.00033569, 0.00067139,
#        0.00076294]), 'sampling_rate': 22050}, 'audio_id': 'LJ019-0046', 'real_or_fake': 'R'}
# {'audio': {'path': 'LJ014-0147_gen.wav', 'array': array([ 0.00204468,  0.00027466, -0.00192261, ...,  0.00109863,
#         0.00119019,  0.00134277]), 'sampling_rate': 22050}, 'audio_id': 'LJ014-0147', 'real_or_fake': 'WF1'}
# {'audio': {'path': 'LJ014-0147_gen.wav', 'array': array([-0.00271606, -0.00302124, -0.00158691, ...,  0.00097656,
#         0.00119019,  0.00167847]), 'sampling_rate': 22050}, 'audio_id': 'LJ014-0147', 'real_or_fake': 'WF2'}
# {'audio': {'path': 'LJ014-0147_generated.wav', 'array': array([-0.00094604, -0.00259399,  0.00021362, ..., -0.00064087,
#        -0.00045776, -0.00082397]), 'sampling_rate': 22050}, 'audio_id': 'LJ014-0147', 'real_or_fake': 'WF3'}
# {'audio': {'path': 'LJ014-0147_gen.wav', 'array': array([-0.00158691, -0.00192261, -0.00180054, ...,  0.00039673,
#         0.00030518,  0.00030518]), 'sampling_rate': 22050}, 'audio_id': 'LJ014-0147', 'real_or_fake': 'WF4'}
# {'audio': {'path': 'LJ014-0147_gen.wav', 'array': array([ 3.05175781e-05,  2.44140625e-04,  1.31225586e-03, ...,
#        -2.44140625e-04, -3.05175781e-05,  9.15527344e-05]), 'sampling_rate': 22050}, 'audio_id': 'LJ014-0147', 'real_or_fake': 'WF5'}
# {'audio': {'path': 'LJ014-0147_gen.wav', 'array': array([-0.00112915, -0.00024414,  0.00100708, ..., -0.00076294,
#        -0.00039673, -0.00045776]), 'sampling_rate': 22050}, 'audio_id': 'LJ014-0147', 'real_or_fake': 'WF6'}
# {'audio': {'path': 'LJ014-0147.wav', 'array': array([ 0.00262451,  0.0007019 , -0.00018311, ...,  0.0010376 ,
#         0.00109863,  0.00140381]), 'sampling_rate': 22050}, 'audio_id': 'LJ014-0147', 'real_or_fake': 'WF7'}
# {'audio': {'path': 'LJ014-0147.wav', 'array': array([ 0.00018311,  0.00054932,  0.00045776, ..., -0.00128174,
#        -0.00134277, -0.00109863]), 'sampling_rate': 22050}, 'audio_id': 'LJ014-0147', 'real_or_fake': 'R'}
